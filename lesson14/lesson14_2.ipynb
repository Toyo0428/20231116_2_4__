# %%
import requests
url = 'https://data.moenv.gov.tw/api/v2/stat_p_90?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=ImportDate desc&format=CSV'
response = requests.get(url)
if response.status_code == 200:
    print("下載成功")
    data=response.text
elif response.status_code >= 400:
    print("下載失敗")    
elif response.status_code > 200:
    print("下載有問題")
# Out:
# 下載成功

# %%
with open("列管公廁.csv",mode='w',encoding='utf8') as file:
    file.write(data)

# %%
#讀取csv檔,成為python的2維資料
import csv
with open("再生能源發電量.csv",mode='r',encoding='utf8',newline='') as file:
    dict_reader = csv.DictReader(file)
    csv_data:list[dict] = list(dict_reader)
    
for item in csv_data:
    if item['日期(年)'] == '2020':
        print(item)
# Out:
# {'日期(年)': '2020', '單位': '千度', '再生能源發電量合計': '15179072', '慣常水力': '3019152', '地熱': '1912', '太陽光電': '6074674', '風力_小計': '2308872', '風力_陸域': '1792791', '風力_離岸': '516081', '生質能_小計': '204718', '生質能_固態': '141366', '生質能_氣態': '63353', '廢棄物': '3569744'}

# %%
#使用pandas 
import pandas as pd
dataFrame=pd.DataFrame(csv_data,columns=['日期(年)','單位','再生能源發電量合計'])
dataFrame
# Out:
#    日期(年)  單位 再生能源發電量合計
# 0   2002  千度   5582829
# 1   2003  千度   6209739
# 2   2004  千度   6584988
# 3   2005  千度   7540945
# 4   2006  千度   7743848
# 5   2007  千度   8324812
# 6   2008  千度   8259060
# 7   2009  千度   7809525
# 8   2010  千度   8639758
# 9   2011  千度   8987061
# 10  2012  千度  10662097
# 11  2013  千度  10855227
# 12  2014  千度   9922382
# 13  2015  千度  10476045
# 14  2016  千度  12730120
# 15  2017  千度  12365425
# 16  2018  千度  12646608
# 17  2019  千度  15258373
# 18  2020  千度  15179072
# 19  2021  千度  17511713
# 20  2022  千度  23844899
